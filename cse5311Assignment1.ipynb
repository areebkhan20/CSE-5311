# %%
def insertionSort(arr):
    n = len(arr)
    if n <= 1:
        return 
    for i in range(1, n):
        key = arr[i]
        j = i-1
        while j >= 0 and key < arr[j]:
            arr[j+1] = arr[j] 
            j -= 1
        arr[j+1] = key

# %%
def selectionSort(arr):
    size = len(array)
    for ind in range(size):
        min_index = ind
        for j in range(ind + 1, size):
            if array[j] < array[min_index]:
                min_index = j
        (array[ind], array[min_index]) = (array[min_index], array[ind])

# %%
def bubbleSort(arr):
    for n in range(len(arr) - 1, 0, -1):
        swapped = False  
        for i in range(n):
            if arr[i] > arr[i + 1]:
                arr[i], arr[i + 1] = arr[i + 1], arr[i]
                swapped = True
        if not swapped:
            break

# %%
# Generating 10 arrays for testing

import numpy as np
import time
import matplotlib.pyplot as plt

min_val = 1  # Minimum value
max_val = 1000  # Maximum value
array_sizes = [5, 10, 20, 40, 80, 160, 320, 640, 1280, 2560]
arrays = [np.random.randint(min_val, max_val + 1, size) for size in array_sizes]

# %%
# Measuring sorting times

sorting_algorithms = [insertionSort, selectionSort, bubbleSort]
sorting_times = {algo.__name__: [] for algo in sorting_algorithms}

for array in arrays:
    for algo in sorting_algorithms:
        arr_copy = array.copy()
        start_time = time.time()
        algo(arr_copy)
        end_time = time.time()
        sorting_times[algo.__name__].append(end_time - start_time)

# %%
# Plotting results
for algo_name, times in sorting_times.items():
    plt.plot(array_sizes, times, label=algo_name)

plt.xlabel("Array Size")
plt.ylabel("Time (seconds)")
plt.title("Sorting Algorithm Performance")
plt.legend()
plt.grid(True)
plt.show()
